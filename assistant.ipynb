# %%
import sys
import openai
import pyttsx3
import speech_recognition as sr
import datetime

engine = pyttsx3.init('sapi5')
voices = engine.getProperty('voices')
engine.setProperty('voice',voices[1].id)


def speak(audio):
    engine.say(audio)
    engine.runAndWait()

def wishMe():
    speak("hey, plese tell me how can i help you ")            
def takeCommand():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("listening......")
        r.pause_threshold = .5 
        audio = r.listen(source)
    try: 
        print("Recognizing....")
        query = r.recognize_google(audio, language='en-in' ) 
        print(f"User Said:  {query}\n ")

    except Exception as e:

        # print(e)
        print("Say that again please......")
        return query       
    return query  


def run():
    usercmd=takeCommand().lower()
    beta =usercmd

    if (beta !="Say that again please......") and ("exit" not in beta):
        openai.api_key = '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'
        response = openai.Completion.create(
        model="text-davinci-002",
        prompt=beta,
        temperature=0.7,
        max_tokens=256,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0 )
            #print(response['choices'][0]['text'])
        text = (response['choices'][0]['text'])
            #text=text.replace(". ",".\n")
        print(text)
        speak(text)
    elif "exit" in beta:
        exit()
    else:
        print(beta)
        run()
        
wishMe()
run()
